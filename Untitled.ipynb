# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('train_small.csv')

# %%
data.head()
# Out:
#    search_id            timestamp  site_id  user_country_id  user_hist_stars  \
# 0          4  2012-12-31 08:59:22        5              219              NaN
# 1          4  2012-12-31 08:59:22        5              219              NaN
# 2          4  2012-12-31 08:59:22        5              219              NaN
# 3          4  2012-12-31 08:59:22        5              219              NaN
# 4          4  2012-12-31 08:59:22        5              219              NaN
#
#    user_hist_paid  listing_country_id  listing_id  listing_stars  \
# 0             NaN                 219        3625              4
# 1             NaN                 219       11622              4
# 2             NaN                 219       11826              5
# 3             NaN                 219       22824              3
# 4             NaN                 219       37581              5
#
#    listing_review_score   ...    competitor6_price_percent_diff  \
# 0                   4.0   ...                               NaN
# 1                   4.0   ...                               NaN
# 2                   4.5   ...                               NaN
# 3                   4.0   ...                               NaN
# 4                   4.5   ...                               NaN
#
#    competitor7_rate  competitor7_has_availability  \
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# 3               NaN                           NaN
# 4               NaN                           NaN
#
#    competitor7_price_percent_diff  competitor8_rate  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
#    competitor8_has_availability  competitor8_price_percent_diff  clicked  \
# 0                           NaN                             NaN        0
# 1                           NaN                             NaN        0
# 2                           NaN                             NaN        0
# 3                           NaN                             NaN        0
# 4                           NaN                             NaN        0
#
#    booking_value  booked
# 0            NaN       0
# 1            NaN       0
# 2            NaN       0
# 3            NaN       0
# 4            NaN       0
#
# [5 rows x 54 columns]

# %%
data.shape
# Out:
# (2380557, 54)

# %%
data.isna().sum()/data.shape[0]
# Out:
# search_id                         0.000000
# timestamp                         0.000000
# site_id                           0.000000
# user_country_id                   0.000000
# user_hist_stars                   0.948424
# user_hist_paid                    0.948124
# listing_country_id                0.000000
# listing_id                        0.000000
# listing_stars                     0.000000
# listing_review_score              0.001464
# is_brand                          0.000000
# location_score1                   0.000000
# location_score2                   0.220953
# log_historical_price              0.000000
# listing_position                  0.000000
# price_usd                         0.000000
# has_promotion                     0.000000
# destination_id                    0.000000
# length_of_stay                    0.000000
# booking_window                    0.000000
# num_adults                        0.000000
# num_kids                          0.000000
# num_rooms                         0.000000
# stay_on_saturday                  0.000000
# log_click_proportion              0.936104
# distance_to_dest                  0.323595
# random_sort                       0.000000
# competitor1_rate                  0.975212
# competitor1_has_availability      0.973258
# competitor1_price_percent_diff    0.980508
# competitor2_rate                  0.594314
# competitor2_has_availability      0.573160
# competitor2_price_percent_diff    0.889114
# competitor3_rate                  0.692698
# competitor3_has_availability      0.668949
# competitor3_price_percent_diff    0.905280
# competitor4_rate                  0.937748
# competitor4_has_availability      0.930570
# competitor4_price_percent_diff    0.973594
# competitor5_rate                  0.552591
# competitor5_has_availability      0.524716
# competitor5_price_percent_diff    0.831483
# competitor6_rate                  0.949744
# competitor6_has_availability      0.945436
# competitor6_price_percent_diff    0.979853
# competitor7_rate                  0.935113
# competitor7_has_availability      0.926551
# competitor7_price_percent_diff    0.971506
# competitor8_rate                  0.616268
# competitor8_has_availability      0.601999
# competitor8_price_percent_diff    0.877046
# clicked                           0.000000
# booking_value                     0.972112
# booked                            0.000000
# dtype: float64

# %%
continuous = ['user_hist_stars','user_hist_paid','listing_stars','listing_review_score','location_score1','location_score2',
    'log_historical_price','listing_position','price_usd','length_of_stay','booking_window','num_adults','num_kids',
      'num_rooms','log_click_proportion','distance_to_dest','booking_value']    

categorical = ['booked','clicked','random_sort','stay_on_saturday','destination_id','has_promotion','is_brand','listing_id',
               'listing_country_id','user_country_id','site_id']

print(len(continuous),len(categorical))
# Out:
# 17 11

# %%
data[continuous].describe()
# Out:
#        user_hist_stars  user_hist_paid  listing_stars  listing_review_score  \
# count    122780.000000   123494.000000   2.380557e+06          2.377071e+06
# mean          3.382814      178.094940   3.180607e+00          3.779416e+00
# std           0.694562      108.568025   1.052086e+00          1.049727e+00
# min           1.500000        0.000000   0.000000e+00          0.000000e+00
# 25%           2.950000      111.090000   3.000000e+00          3.500000e+00
# 50%           3.450000      152.620000   3.000000e+00          4.000000e+00
# 75%           3.950000      215.950000   4.000000e+00          4.500000e+00
# max           5.000000     1507.120000   5.000000e+00          5.000000e+00
#
#        location_score1  location_score2  log_historical_price  \
# count     2.380557e+06     1.854565e+06          2.380557e+06
# mean      2.878558e+00     1.310325e-01          4.311779e+00
# std       1.536947e+00     1.605939e-01          1.842699e+00
# min       0.000000e+00     0.000000e+00          0.000000e+00
# 25%       1.790000e+00     1.910000e-02          4.440000e+00
# 50%       2.770000e+00     6.940000e-02          4.910000e+00
# 75%       4.060000e+00     1.810000e-01          5.310000e+00
# max       6.980000e+00     1.000000e+00          6.210000e+00
#
#        listing_position     price_usd  length_of_stay  booking_window  \
# count      2.380557e+06  2.380557e+06    2.380557e+06    2.380557e+06
# mean       1.686763e+01  2.915203e+02    2.393825e+00    3.768373e+01
# std        1.042970e+01  2.288292e+04    2.062891e+00    5.211484e+01
# min        1.000000e+00  0.000000e+00    1.000000e+00    0.000000e+00
# 25%        8.000000e+00  8.500000e+01    1.000000e+00    4.000000e+00
# 50%        1.600000e+01  1.222500e+02    2.000000e+00    1.700000e+01
# 75%        2.600000e+01  1.853100e+02    3.000000e+00    4.900000e+01
# max        4.000000e+01  1.972633e+07    5.700000e+01    4.980000e+02
#
#          num_adults      num_kids     num_rooms  log_click_proportion  \
# count  2.380557e+06  2.380557e+06  2.380557e+06         152107.000000
# mean   1.969876e+00  3.491460e-01  1.110318e+00            -24.398076
# std    8.580772e-01  7.276573e-01  4.200432e-01             16.129689
# min    1.000000e+00  0.000000e+00  1.000000e+00           -326.567500
# 25%    2.000000e+00  0.000000e+00  1.000000e+00            -31.267400
# 50%    2.000000e+00  0.000000e+00  1.000000e+00            -20.440800
# 75%    2.000000e+00  0.000000e+00  1.000000e+00            -13.498000
# max    9.000000e+00  9.000000e+00  8.000000e+00             -3.099500
#
#        distance_to_dest  booking_value
# count      1.610221e+06   66388.000000
# mean       1.315759e+03     383.229069
# std        2.029315e+03     527.019882
# min        1.000000e-02       0.000000
# 25%        1.427400e+02     124.150000
# 50%        3.923000e+02     219.185000
# 75%        1.526180e+03     432.125000
# max        1.163779e+04   20238.720000

# %%
def plot_histograms(nrow,ncol):
    for i,col in enumerate(continuous):
        sp = plt.subplot(nrow,ncol,i+1)
        data[col]=pd.to_numeric(data[col],errors='coerce')      
        sns.distplot(data[col].dropna(),kde=False,ax=sp)
    plt.figure(figsize=(18,12))    
    plt.tight_layout()    
    plt.show()

# %%
plot_histograms(5,4)
# Out:
# /home/divyansh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
